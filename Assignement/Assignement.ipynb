# %%
#Understand the Data

# %%
import pandas as pd

df = pd.read_csv('groceries.csv', header=None)
transactions = df.apply(lambda row: row.dropna().tolist(), axis=1).tolist()
#How many transactions are in the dataset?
n_transactions = len(transactions)
print(n_transactions)

print(f"Number of transactions: {len(transactions)}")
print("First transaction:", transactions[0])
print("Middle transaction:", transactions[len(transactions) // 2])
print("Last transaction:", transactions[-1])
# Out:
# C:\Users\Admin\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\Admin\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (
# 9835
# Number of transactions: 9835
# First transaction: ['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups']
# Middle transaction: ['domestic eggs']
# Last transaction: ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags']

# %%
# How many different grocery items are included? 
items = set()
for t in transactions:
    items.update(t)

print(f"Number of unique items: {len(items)}")
# Out:
# Number of unique items: 169

# %%
#What are the 10 most frequently purchased items? 

from collections import Counter

item_counts = Counter()
for t in transactions:
    item_counts.update(t)

print(item_counts.most_common(10))
# Out:
# [('whole milk', 2513), ('other vegetables', 1903), ('rolls/buns', 1809), ('soda', 1715), ('yogurt', 1372), ('bottled water', 1087), ('root vegetables', 1072), ('tropical fruit', 1032), ('shopping bags', 969), ('sausage', 924)]

# %%
#Question 2: Frequent Itemsets

# %%
#Question 2: Frequent Itemsets Identify some products that are frequently purchased together.


from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
basket = pd.DataFrame(te_array, columns=te.columns_)

print(basket.shape)
# Out:
# C:\Users\Admin\AppData\Local\anaconda3\Lib\site-packages\mlxtend\preprocessing\copy_transformer.py:10: UserWarning: A NumPy version >=2.0.0 and <2.8.0 is required for this version of SciPy (detected version 1.26.4)
#   from scipy.sparse import issparse
# C:\Users\Admin\AppData\Local\anaconda3\Lib\site-packages\scipy\sparse\_sputils.py:17: FutureWarning: In the future `np.long` will be defined as the corresponding NumPy scalar.
#   np.uintc, np.long, np.ulong, np.longlong, np.ulonglong,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 #Question 2: Frequent Itemsets Identify some products that are frequently purchased together.
# ----> 4 from mlxtend.preprocessing import TransactionEncoder
#       6 te = TransactionEncoder()
#       7 te_array = te.fit(transactions).transform(transactions)
#
# ...
